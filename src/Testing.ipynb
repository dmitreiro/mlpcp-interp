# %%
import pandas as pd;
import numpy as np;
import random;
import matplotlib.pyplot as plt;
from sklearn.preprocessing import StandardScaler,MinMaxScaler;
from sklearn.model_selection import train_test_split;
from sklearn.linear_model import LinearRegression;
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error,mean_absolute_percentage_error; 
from sklearn.ensemble import RandomForestRegressor;
from sklearn.svm import SVR;
import xgboost as xgb;
from IPython.core.interactiveshell import InteractiveShell;
from IPython.display import display;
import time;
import joblib;
from sklearn.multioutput import MultiOutputRegressor;

#IMPORT THE FILTERED DATA FOR TESTING
#THE DATA SHOULD ALREADY BE NORMALIZED
#THE DATA SHOULD ONLY CONTAIN USEFUL SIMULATIONS (Fxy20>Fxy19)
#CHANGE NUMBERS ON THE MODEL NAME FILE FOR THE DESIRED MODEL

X_test = pd.read_csv(r'C:\Users\gambo\Drive\Universidade de Aveiro\OP_DPE_2023 24_João_Marques_(Dissertação_ML) - General\Machine Learning\TEST\X_test.csv')

#DEFINE X COLUMNS
l=[]
for x in range(1,21):
    l.append("Force_x_"+str(x))
    l.append("Force_y_"+str(x))
    for p in range(1,565):#elements number
        l.append("Strain_x_"+str(p)+"_"+str(x))
        l.append("Strain_y_"+str(p)+"_"+str(x))
        l.append("Strain_xy_"+str(p)+"_"+str(x))
X_test.columns = l

display(X_test)

#IMPORT THE FILTERED DATA FOR TRAINING
#THE DATA SHOULD ALREADY BE NORMALIZED
#THE DATA SHOULD ONLY CONTAIN USEFUL SIMULATIONS (Fxy20>Fxy19)
#COPY TRAINING SET FROM "(...)\Datasets\Datatrain\XXXX\N\ to (...)\TRAIN
#CHANGE NUMBERS ON THE TRAINING NAME FILE FOR THE DESIRED MODEL

y_test = pd.read_csv(r'C:\Users\gambo\Drive\Universidade de Aveiro\OP_DPE_2023 24_João_Marques_(Dissertação_ML) - General\Machine Learning\TEST\y_test.csv')
display(y_test)

#LOAD TRAINED MODEL
#ADAPT TO NAME ON JOBLIB EG: modelo_xgboost_2500_3
modelo = joblib.load('modelo_xgboost_3000_1.joblib')
print(modelo.get_params())

#PREDICT TRAINING VALUES 
y_test_pred = modelo.predict(X_test)

#PERFORMANCE ON TRAINING
r2_test = r2_score(y_test, y_test_pred)
mae_test = mean_absolute_error(y_test, y_test_pred)
mape_test = mean_absolute_percentage_error(y_test, y_test_pred)
print(f'R-squared on Test Data: {r2_test}')
print(f'MAE on Test Data: {mae_test}')
print(f'MAPE on Test Data: {mape_test}')
# Out:
#      Force_x_1  Force_y_1  Strain_x_1_1  Strain_y_1_1  Strain_xy_1_1  \
# 0     0.544684   1.350489      0.272692      0.504356      -0.719673
# 1     0.071813  -0.142479     -0.396742      0.461021       0.562074
# 2    -0.549545  -0.347513      1.954188     -1.937145       0.492601
# 3     0.789273   0.562210      2.197156     -1.933890       0.749484
# 4    -1.072066  -1.148756      0.468333     -0.799838       0.008522
# ..         ...        ...           ...           ...            ...
# 465   2.156402   2.040210      0.466317     -0.278313       0.540569
# 466   0.279182   0.094902     -0.990240      0.597869      -0.593142
# 467  -0.542152  -0.455639     -1.493494      1.290133      -2.034555
# 468  -0.764028  -0.751666     -1.790203      1.254985      -2.230868
# 469  -0.102563  -0.756575     -0.408871      0.767766       0.036555
#
#      Strain_x_2_1  Strain_y_2_1  Strain_xy_2_1  Strain_x_3_1  Strain_y_3_1  \
# 0        0.311786      0.494655      -0.786848      0.389690      0.479197
# 1       -0.357166      0.430551       0.643741     -0.271915      0.365518
# 2        1.949796     -1.940128       0.358612      1.928444     -1.929803
# 3        2.221202     -1.955973       0.529869      2.232982     -1.969615
# 4        0.404401     -0.766543      -0.117143      0.218390     -0.646285
# ..            ...           ...            ...           ...           ...
# 465      0.477483     -0.279906       0.396348      0.474375     -0.263609
# 466     -1.010867      0.597604      -0.521431     -1.060125      0.602175
# 467     -1.517767      1.297660      -2.271016     -1.594953      1.335924
# 468     -1.829880      1.263669      -2.182319     -1.938319      1.294837
# 469     -0.366839      0.750450       0.081457     -0.275890      0.714478
#
#      ...  Strain_xy_561_20  Strain_x_562_20  Strain_y_562_20  \
# 0    ...         -0.003221         0.759726        -0.761406
# 1    ...         -0.171231         0.948332        -0.946097
# 2    ...          1.145407        -1.848182         1.717656
# 3    ...         -0.621055        -3.190975         3.409844
# 4    ...         -0.547428        -1.777254         1.923653
# ..   ...               ...              ...              ...
# 465  ...         -0.247728        -1.990792         1.962775
# 466  ...         -0.368339        -0.169723         0.116297
# 467  ...         -1.895954         0.361598        -0.264838
# 468  ...         -1.601567         0.292383        -0.259001
# 469  ...         -1.214526         1.205895        -1.147381
#
#      Strain_xy_562_20  Strain_x_563_20  Strain_y_563_20  Strain_xy_563_20  \
# 0           -0.145181         0.780932        -0.728344         -0.273705
# 1           -0.279143         0.979176        -0.974132         -0.515744
# 2            1.493780        -1.967953         1.810813          2.104995
# 3            0.123889        -2.892830         3.273496          1.217434
# 4           -0.406023        -1.541705         1.619027         -0.044659
# ..                ...              ...              ...               ...
# 465         -0.124430        -1.996382         2.024692          0.566022
# 466         -0.537883        -0.094330        -0.091518         -0.991312
# 467         -2.030337         0.250138         0.205341         -1.513176
# 468         -1.738739         0.364983        -0.380259         -1.919673
# 469         -1.438093         1.299317        -1.196204         -1.626076
#
#      Strain_x_564_20  Strain_y_564_20  Strain_xy_564_20
# 0           0.788022        -0.650951         -0.246308
# 1           0.985064        -0.976607         -0.410333
# 2          -2.169807         1.957719          2.036187
# 3          -2.562853         3.130730          0.807730
# 4          -1.287007         1.344564         -0.341636
# ..               ...              ...               ...
# 465        -1.923403         2.038090          0.255667
# 466         0.039095        -0.321180         -1.240982
# 467         0.393271         0.435290         -1.426086
# 468         0.590742        -0.660428         -1.939046
# 469         1.391233        -1.256219         -1.389043
#
# [470 rows x 33880 columns]
#           F       G       N  sigma0       k      n
# 0    0.1693  0.4500  1.7887  164.43  696.00  0.195
# 1    0.3525  0.2810  3.8165  206.68  545.03  0.193
# 2    0.1391  0.2057  0.9213  135.37  640.74  0.290
# 3    0.1917  0.1672  0.4801  173.11  653.14  0.252
# 4    0.2494  0.1567  0.8046  140.12  341.87  0.276
# ..      ...     ...     ...     ...     ...    ...
# 465  0.1643  0.2189  0.7151  264.62  694.92  0.291
# 466  0.2215  0.1827  1.7927  214.67  431.37  0.287
# 467  0.3481  0.3731  0.9938  181.75  508.69  0.284
# 468  0.2867  0.2636  1.3914  174.56  365.05  0.298
# 469  0.6622  0.3107  4.3156  198.87  557.36  0.192
#
# [470 rows x 6 columns]
# C:\Users\gambo\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [16:26:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\data\../common/error_msg.h:80: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
#   warnings.warn(smsg, UserWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 50
#      47 #LOAD TRAINED MODEL
#      48 #ADAPT TO NAME ON JOBLIB EG: modelo_xgboost_2500_3
#      49 modelo = joblib.load('modelo_xgboost_3000_1.joblib')
# ---> 50 print(modelo.get_params())
#      52 #PREDICT TRAINING VALUES
#      53 y_test_pred = modelo.predict(X_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:172, in BaseEstimator.get_params(self, deep)
#     170 value = getattr(self, key)
#     171 if deep and hasattr(value, "get_params") and not isinstance(value, type):
# --> 172     deep_items = value.get_params().items()
#     173     out.update((key + "__" + k, val) for k, val in deep_items)
#     174 out[key] = value
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:851, in XGBModel.get_params(self, deep)
#     849 cp = copy.copy(self)
#     850 cp.__class__ = cp.__class__.__bases__[0]
# --> 851 params.update(cp.__class__.get_params(cp, deep))
#     852 # if kwargs is a dict, update params accordingly
#     853 if hasattr(self, "kwargs") and isinstance(self.kwargs, dict):
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:848, in XGBModel.get_params(self, deep)
#     841 """Get parameters."""
#     842 # Based on: https://stackoverflow.com/questions/59248211
#     843 # The basic flow in `get_params` is:
#     844 # 0. Return parameters in subclass first, by using inspect.
#     845 # 1. Return parameters in `XGBModel` (the base class).
#     846 # 2. Return whatever in `**kwargs`.
#     847 # 3. Merge them.
# --> 848 params = super().get_params(deep)
#     849 cp = copy.copy(self)
#     850 cp.__class__ = cp.__class__.__bases__[0]
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:170, in BaseEstimator.get_params(self, deep)
#     168 out = dict()
#     169 for key in self._get_param_names():
# --> 170     value = getattr(self, key)
#     171     if deep and hasattr(value, "get_params") and not isinstance(value, type):
#     172         deep_items = value.get_params().items()
#
# AttributeError: 'XGBModel' object has no attribute 'device'

# %% [markdown]
# # IMPORT LIBRARY

# %%
import pandas as pd;
import numpy as np;
import random;
import matplotlib.pyplot as plt;
from sklearn.preprocessing import StandardScaler,MinMaxScaler;
from sklearn.model_selection import train_test_split;
from sklearn.linear_model import LinearRegression;
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error,mean_absolute_percentage_error; 
from sklearn.ensemble import RandomForestRegressor;
from sklearn.svm import SVR;
import xgboost as xgb;
from IPython.core.interactiveshell import InteractiveShell;
from IPython.display import display;
import time;
import joblib;
from sklearn.multioutput import MultiOutputRegressor;

# %% [markdown]
# # CHOOSE DATASET FOR TESTING

# %%
#IMPORT THE FILTERED DATA FOR TESTING
#THE DATA SHOULD ALREADY BE NORMALIZED
#THE DATA SHOULD ONLY CONTAIN USEFUL SIMULATIONS (Fxy20>Fxy19)
#CHANGE NUMBERS ON THE MODEL NAME FILE FOR THE DESIRED MODEL

X_test = pd.read_csv(r'C:\Users\gambo\Drive\Universidade de Aveiro\OP_DPE_2023 24_João_Marques_(Dissertação_ML) - General\Machine Learning\TEST\X_test.csv')

#DEFINE X COLUMNS
l=[]
for x in range(1,21):
    l.append("Force_x_"+str(x))
    l.append("Force_y_"+str(x))
    for p in range(1,565):#elements number
        l.append("Strain_x_"+str(p)+"_"+str(x))
        l.append("Strain_y_"+str(p)+"_"+str(x))
        l.append("Strain_xy_"+str(p)+"_"+str(x))
X_test.columns = l

display(X_test)
# Out:
#      Force_x_1  Force_y_1  Strain_x_1_1  Strain_y_1_1  Strain_xy_1_1  \
# 0     0.544684   1.350489      0.272692      0.504356      -0.719673
# 1     0.071813  -0.142479     -0.396742      0.461021       0.562074
# 2    -0.549545  -0.347513      1.954188     -1.937145       0.492601
# 3     0.789273   0.562210      2.197156     -1.933890       0.749484
# 4    -1.072066  -1.148756      0.468333     -0.799838       0.008522
# ..         ...        ...           ...           ...            ...
# 465   2.156402   2.040210      0.466317     -0.278313       0.540569
# 466   0.279182   0.094902     -0.990240      0.597869      -0.593142
# 467  -0.542152  -0.455639     -1.493494      1.290133      -2.034555
# 468  -0.764028  -0.751666     -1.790203      1.254985      -2.230868
# 469  -0.102563  -0.756575     -0.408871      0.767766       0.036555
#
#      Strain_x_2_1  Strain_y_2_1  Strain_xy_2_1  Strain_x_3_1  Strain_y_3_1  \
# 0        0.311786      0.494655      -0.786848      0.389690      0.479197
# 1       -0.357166      0.430551       0.643741     -0.271915      0.365518
# 2        1.949796     -1.940128       0.358612      1.928444     -1.929803
# 3        2.221202     -1.955973       0.529869      2.232982     -1.969615
# 4        0.404401     -0.766543      -0.117143      0.218390     -0.646285
# ..            ...           ...            ...           ...           ...
# 465      0.477483     -0.279906       0.396348      0.474375     -0.263609
# 466     -1.010867      0.597604      -0.521431     -1.060125      0.602175
# 467     -1.517767      1.297660      -2.271016     -1.594953      1.335924
# 468     -1.829880      1.263669      -2.182319     -1.938319      1.294837
# 469     -0.366839      0.750450       0.081457     -0.275890      0.714478
#
#      ...  Strain_xy_561_20  Strain_x_562_20  Strain_y_562_20  \
# 0    ...         -0.003221         0.759726        -0.761406
# 1    ...         -0.171231         0.948332        -0.946097
# 2    ...          1.145407        -1.848182         1.717656
# 3    ...         -0.621055        -3.190975         3.409844
# 4    ...         -0.547428        -1.777254         1.923653
# ..   ...               ...              ...              ...
# 465  ...         -0.247728        -1.990792         1.962775
# 466  ...         -0.368339        -0.169723         0.116297
# 467  ...         -1.895954         0.361598        -0.264838
# 468  ...         -1.601567         0.292383        -0.259001
# 469  ...         -1.214526         1.205895        -1.147381
#
#      Strain_xy_562_20  Strain_x_563_20  Strain_y_563_20  Strain_xy_563_20  \
# 0           -0.145181         0.780932        -0.728344         -0.273705
# 1           -0.279143         0.979176        -0.974132         -0.515744
# 2            1.493780        -1.967953         1.810813          2.104995
# 3            0.123889        -2.892830         3.273496          1.217434
# 4           -0.406023        -1.541705         1.619027         -0.044659
# ..                ...              ...              ...               ...
# 465         -0.124430        -1.996382         2.024692          0.566022
# 466         -0.537883        -0.094330        -0.091518         -0.991312
# 467         -2.030337         0.250138         0.205341         -1.513176
# 468         -1.738739         0.364983        -0.380259         -1.919673
# 469         -1.438093         1.299317        -1.196204         -1.626076
#
#      Strain_x_564_20  Strain_y_564_20  Strain_xy_564_20
# 0           0.788022        -0.650951         -0.246308
# 1           0.985064        -0.976607         -0.410333
# 2          -2.169807         1.957719          2.036187
# 3          -2.562853         3.130730          0.807730
# 4          -1.287007         1.344564         -0.341636
# ..               ...              ...               ...
# 465        -1.923403         2.038090          0.255667
# 466         0.039095        -0.321180         -1.240982
# 467         0.393271         0.435290         -1.426086
# 468         0.590742        -0.660428         -1.939046
# 469         1.391233        -1.256219         -1.389043
#
# [470 rows x 33880 columns]

# %%
#IMPORT THE FILTERED DATA FOR TRAINING
#THE DATA SHOULD ALREADY BE NORMALIZED
#THE DATA SHOULD ONLY CONTAIN USEFUL SIMULATIONS (Fxy20>Fxy19)
#COPY TRAINING SET FROM "(...)\Datasets\Datatrain\XXXX\N\ to (...)\TRAIN
#CHANGE NUMBERS ON THE TRAINING NAME FILE FOR THE DESIRED MODEL

y_test = pd.read_csv(r'C:\Users\gambo\Drive\Universidade de Aveiro\OP_DPE_2023 24_João_Marques_(Dissertação_ML) - General\Machine Learning\TEST\y_test.csv')
display(y_test)
# Out:
#           F       G       N  sigma0       k      n
# 0    0.1693  0.4500  1.7887  164.43  696.00  0.195
# 1    0.3525  0.2810  3.8165  206.68  545.03  0.193
# 2    0.1391  0.2057  0.9213  135.37  640.74  0.290
# 3    0.1917  0.1672  0.4801  173.11  653.14  0.252
# 4    0.2494  0.1567  0.8046  140.12  341.87  0.276
# ..      ...     ...     ...     ...     ...    ...
# 465  0.1643  0.2189  0.7151  264.62  694.92  0.291
# 466  0.2215  0.1827  1.7927  214.67  431.37  0.287
# 467  0.3481  0.3731  0.9938  181.75  508.69  0.284
# 468  0.2867  0.2636  1.3914  174.56  365.05  0.298
# 469  0.6622  0.3107  4.3156  198.87  557.36  0.192
#
# [470 rows x 6 columns]

# %% [markdown]
# # TEST MODEL

# %%
#LOAD TRAINED MODEL
#ADAPT TO NAME ON JOBLIB EG: modelo_xgboost_2500_3
modelo = joblib.load('modelo_xgboost_3000_1.joblib')
print(modelo.get_params())
# Out:
# Training duration: 346.73399999999674

# %%
#PREDICT TRAINING VALUES 
y_test_pred = modelo.predict(X_test)

#PERFORMANCE ON TRAINING
r2_test = r2_score(y_test, y_test_pred)
mae_test = mean_absolute_error(y_test, y_test_pred)
mape_test = mean_absolute_percentage_error(y_test, y_test_pred)
print(f'R-squared on Test Data: {r2_test}')
print(f'MAE on Test Data: {mae_test}')
print(f'MAPE on Test Data: {mape_test}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 #PREDICT TRAINING VALUES
# ----> 2 y_test_pred = modelo.predict(X_test)
#       4 #PERFORMANCE ON TRAINING
#       5 r2_test = r2_score(y_test, y_test_pred)
#
# NameError: name 'modelo' is not defined
